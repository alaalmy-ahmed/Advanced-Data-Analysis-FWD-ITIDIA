# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings 

# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
youtube = pd.read_csv('youtubedata/YoutubeDataCleaned.csv', encoding = 'unicode_escape')
youtube.head()
# Out:
#         CITY STATE COUNTRY trending_date  \
# 0  Covington    KY     USA      18.25.02
# 1  Covington    KY     USA      18.26.02
# 2  Covington    KY     USA      18.01.03
# 3  Covington    KY     USA      18.02.03
# 4  Covington    KY     USA      18.03.03
#
#                                                title          Channel_title  \
# 0        Cheap Thrills - Sia / Tina Boo Choreography  1MILLION Dance Studio
# 1        Cheap Thrills - Sia / Tina Boo Choreography  1MILLION Dance Studio
# 2  FRIENDS - Marshmello & Anne-Marie / Tina Boo C...  1MILLION Dance Studio
# 3  FRIENDS - Marshmello & Anne-Marie / Tina Boo C...  1MILLION Dance Studio
# 4  FRIENDS - Marshmello & Anne-Marie / Tina Boo C...  1MILLION Dance Studio
#
#    category_id              publish_time  \
# 0           24  2018-02-19T12:00:02.000Z
# 1           24  2018-02-19T12:00:02.000Z
# 2           24  2018-02-28T09:00:03.000Z
# 3           24  2018-02-28T09:00:03.000Z
# 4           24  2018-02-28T09:00:03.000Z
#
#                                                 tags   views  likes  dislikes  \
# 0  choreography"|"1million dance studio"|"ìë°ë...  601159  27962       336
# 1  choreography"|"1million dance studio"|"ìë°ë...  627933  28580       340
# 2  choreography"|"1million dance studio"|"ìë°ë...  384249  26271       238
# 3  choreography"|"1million dance studio"|"ìë°ë...  513455  31505       279
# 4  choreography"|"1million dance studio"|"ìë°ë...  607740  35180       314
#
#    comment_count                                  thumbnail_link  \
# 0            444  https://i.ytimg.com/vi/QRq0pkr2TWM/default.jpg
# 1            444  https://i.ytimg.com/vi/QRq0pkr2TWM/default.jpg
# 2            540  https://i.ytimg.com/vi/_xwX82Y0Oro/default.jpg
# 3            623  https://i.ytimg.com/vi/_xwX82Y0Oro/default.jpg
# 4            672  https://i.ytimg.com/vi/_xwX82Y0Oro/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False

# %% [markdown]
# - General Idea the columns and the dataset

# %%
youtube.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22524 entries, 0 to 22523
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CITY                    22524 non-null  object
#  1   STATE                   22524 non-null  object
#  2   COUNTRY                 22524 non-null  object
#  3   trending_date           22524 non-null  object
#  4   title                   22524 non-null  object
#  5   Channel_title           22524 non-null  object
#  6   category_id             22524 non-null  int64
#  7   publish_time            22524 non-null  object
#  8   tags                    22524 non-null  object
#  9   views                   22524 non-null  int64
#  10  likes                   22524 non-null  int64
#  11  dislikes                22524 non-null  int64
#  12  comment_count           22524 non-null  int64
#  13  thumbnail_link          22524 non-null  object
#  14  comments_disabled       22524 non-null  bool
#  15  ratings_disabled        22524 non-null  bool
#  16  video_error_or_removed  22524 non-null  bool
# dtypes: bool(3), int64(5), object(9)
# memory usage: 2.5+ MB

# %% [markdown]
# - Looking for any null values.

# %%
youtube.isnull().sum()
# Out:
# CITY                      0
# STATE                     0
# COUNTRY                   0
# trending_date             0
# title                     0
# Channel_title             0
# category_id               0
# publish_time              0
# tags                      0
# views                     0
# likes                     0
# dislikes                  0
# comment_count             0
# thumbnail_link            0
# comments_disabled         0
# ratings_disabled          0
# video_error_or_removed    0
# dtype: int64

# %% [markdown]
# - Looking for any Duplicated values.

# %%
youtube.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - A Description about the Numerical Columns of the  data.

# %%
youtube.select_dtypes(exclude='object').describe().T
# Out:
#                  count          mean           std    min        25%  \
# category_id    22524.0  2.015699e+01  7.618999e+00    1.0      17.00
# views          22524.0  1.329987e+06  4.242973e+06  549.0  127517.75
# likes          22524.0  4.620251e+04  1.473514e+05    0.0    2547.00
# dislikes       22524.0  2.321051e+03  2.595470e+04    0.0     115.00
# comment_count  22524.0  5.532497e+03  2.357472e+04    0.0     352.00
#
#                     50%         75%          max
# category_id        24.0       25.00         43.0
# views          376715.5  1116801.00  149376127.0
# likes           10778.0    32743.75    3093544.0
# dislikes          380.0     1225.00    1643059.0
# comment_count    1190.0     3695.25     827755.0

# %% [markdown]
# - A Description about the Categorical Columns of the  data.

# %%
youtube.select_dtypes(include='object').describe().T
# Out:
#                 count unique                                             top  \
# CITY            22524    147                                         Atlanta
# STATE           22524     50                                              CA
# COUNTRY         22524      1                                             USA
# trending_date   22524    125                                        17.26.11
# title           22524   4448                                 Maroon 5 - Wait
# Channel_title   22524   1761                                            ESPN
# publish_time    22524   4333                        2018-03-07T17:00:02.000Z
# tags            22524   4031                                          [none]
# thumbnail_link  22524   4389  https://i.ytimg.com/vi/H0g4JxKp4fc/default.jpg
#
#                  freq
# CITY             1871
# STATE            2861
# COUNTRY         22524
# trending_date     191
# title              18
# Channel_title     122
# publish_time       25
# tags              950
# thumbnail_link     16

# %% [markdown]
# - Taking a copy from the original dataset so we can edit it.

# %%
df = youtube.copy()

# %% [markdown]
# - Fixing the Time and Data columns As they are defined as Object datatype.

# %%
df['trending_date'] = \
     pd.to_datetime(('20' + df['trending_date']).str.replace('.',  '-'), format="%Y-%d-%m")
df['publish_time'] = \
    pd.to_datetime(df['publish_time'])

# %% [markdown]
# -  Drop the Unnecessary columns

# %%
drop_cols = ['COUNTRY', 'tags', 'thumbnail_link']
df.drop(drop_cols, axis=1, inplace=True)

# %% [markdown]
# - Mapping Some columns for the Analysis.

# %%
mapping = {True:'Yes', False:'No'}
cols = ['comments_disabled', 'ratings_disabled', 'video_error_or_removed']
for col in cols:
    df[col] = df[col].map(mapping)

# %%
df.to_csv('new_youtube.csv')

# %%
df.head()
# Out:
#         CITY STATE trending_date  \
# 0  Covington    KY    2018-02-25
# 1  Covington    KY    2018-02-26
# 2  Covington    KY    2018-03-01
# 3  Covington    KY    2018-03-02
# 4  Covington    KY    2018-03-03
#
#                                                title          Channel_title  \
# 0        Cheap Thrills - Sia / Tina Boo Choreography  1MILLION Dance Studio
# 1        Cheap Thrills - Sia / Tina Boo Choreography  1MILLION Dance Studio
# 2  FRIENDS - Marshmello & Anne-Marie / Tina Boo C...  1MILLION Dance Studio
# 3  FRIENDS - Marshmello & Anne-Marie / Tina Boo C...  1MILLION Dance Studio
# 4  FRIENDS - Marshmello & Anne-Marie / Tina Boo C...  1MILLION Dance Studio
#
#    category_id              publish_time   views  likes  dislikes  \
# 0           24 2018-02-19 12:00:02+00:00  601159  27962       336
# 1           24 2018-02-19 12:00:02+00:00  627933  28580       340
# 2           24 2018-02-28 09:00:03+00:00  384249  26271       238
# 3           24 2018-02-28 09:00:03+00:00  513455  31505       279
# 4           24 2018-02-28 09:00:03+00:00  607740  35180       314
#
#    comment_count comments_disabled ratings_disabled video_error_or_removed
# 0            444                No               No                     No
# 1            444                No               No                     No
# 2            540                No               No                     No
# 3            623                No               No                     No
# 4            672                No               No                     No

# %%
df.likes.corr(df.dislikes)
# Out:
# 0.44871785410548487
